# %% [markdown]
# # #5 Movie Metrics

# %%
import polars as pl

# %%
users = pl.read_csv(
	'user_activity/users.csv', 
	try_parse_dates=True, 
	new_columns=['user_id']
)

activity = pl.read_csv(
	'user_activity/activity.csv', 
	try_parse_dates=True, 
	columns=['user_id', 'date', 'movie_name', 'finished']
)

# %%
user_act = users.join(activity,on='user_id')
user_act

# %%
user_act.group_by(['user_id', 'movie_name'], maintain_order=True).agg(pl.min("date"))
